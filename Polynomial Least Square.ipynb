# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([2, 3.5, 3.2, 5.8, 10.5, 17.2])

degree = 2
coefficients = np.polyfit(x, y, degree)
poly = np.poly1d(coefficients)

x_fit = np.linspace(x.min(), x.max(), 100)
y_fit = poly(x_fit)

plt.scatter(x, y, label='Original data')
plt.plot(x_fit, y_fit, color='red', label=f'Fit (degree {degree})')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
print(f"Coefficients: {coefficients}")
plt.show()
# Out:
# Coefficients: [ 0.82142857 -1.26142857  2.65714286]
